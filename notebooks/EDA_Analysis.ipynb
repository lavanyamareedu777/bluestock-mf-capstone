# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

# %%
import pandas as pd

nav = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\processed\nav_history_clean.csv"
)

nav.head()
# Out:
#          date  amfi_code    nav
# 0  2024-01-01       1001  25.67
# 1  2024-01-02       1001  25.80
# 2  2024-01-03       1002  18.45
# 3  2024-01-04       1002  18.60

# %%
import plotly.express as px

nav["date"] = pd.to_datetime(nav["date"])

fig = px.line(
    nav,
    x="date",
    y="nav",
    color="amfi_code",
    title="NAV Trend Analysis"
)

fig.show()

# %%
nav.head()
# Out:
#         date  amfi_code    nav
# 0 2024-01-01       1001  25.67
# 1 2024-01-02       1001  25.80
# 2 2024-01-03       1002  18.45
# 3 2024-01-04       1002  18.60

# %%
import pandas as pd
import plotly.express as px

nav = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\processed\nav_history_clean.csv"
)

nav["date"] = pd.to_datetime(nav["date"])

nav.head()
# Out:
#         date  amfi_code    nav
# 0 2024-01-01       1001  25.67
# 1 2024-01-02       1001  25.80
# 2 2024-01-03       1002  18.45
# 3 2024-01-04       1002  18.60

# %%
fig = px.line(
    nav,
    x="date",
    y="nav",
    color="amfi_code",
    title="Daily NAV Trend (2022-2026)"
)

fig.show()

# %%
fig.add_vrect(
    x0="2023-01-01",
    x1="2023-12-31",
    annotation_text="2023 Bull Run",
    opacity=0.2
)

fig.show()

# %%
fig.add_vrect(
    x0="2024-01-01",
    x1="2024-06-30",
    annotation_text="2024 Correction",
    opacity=0.2
)

fig.show()

# %%
fig.write_html(
    r"E:\bluestock_mf_capstone\reports\charts\nav_trend.html"
)

# %%
aum = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\raw\03_aum_by_fund_house.csv"
)

aum.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
print(aum.columns)
# Out:
# Index(['date', 'fund_house', 'aum_lakh_crore', 'aum_crore', 'num_schemes'], dtype='object')

# %%
aum["date"] = pd.to_datetime(aum["date"])
aum["year"] = aum["date"].dt.year

aum.head()
# Out:
#         date           fund_house  aum_lakh_crore  aum_crore  num_schemes  \
# 0 2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1 2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2 2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3 2022-03-31      Nippon India MF            2.70     270000          177
# 4 2022-03-31    Kotak Mahindra MF            2.70     270000          168
#
#    year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))

sns.barplot(
    data=aum,
    x="year",
    y="aum_lakh_crore",
    hue="fund_house"
)

plt.title("AUM Growth by Fund House")
plt.xlabel("Year")
plt.ylabel("AUM (Lakh Crore)")
plt.xticks(rotation=0)

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=aum,
    x="year",
    y="aum_lakh_crore",
    hue="fund_house"
)

plt.title("AUM Growth by Fund House")
plt.xlabel("Year")
plt.ylabel("AUM (Lakh Crore)")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\aum_growth.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Finding 2
#
# SBI Mutual Fund maintained the highest AUM among fund houses, demonstrating strong market leadership and investor trust.

# %%
print("SBI Mutual Fund maintained the highest AUM among fund houses, demonstrating strong market leadership and investor trust.")
# Out:
# SBI Mutual Fund maintained the highest AUM among fund houses, demonstrating strong market leadership and investor trust.

# %% [markdown]
# ### Finding 2
#
# SBI Mutual Fund maintained the highest AUM among fund houses, demonstrating strong market leadership and investor trust.

# %%
sip = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\raw\04_monthly_sip_inflows.csv"
)

sip.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
print(sip.columns)
# Out:
# Index(['month', 'sip_inflow_crore', 'active_sip_accounts_crore',
#        'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct'],
#       dtype='object')

# %%
sip["month"] = pd.to_datetime(sip["month"])

sip.head()
# Out:
#        month  sip_inflow_crore  active_sip_accounts_crore  \
# 0 2022-01-01             11517                       4.91
# 1 2022-02-01             11438                       4.93
# 2 2022-03-01             12328                       5.09
# 3 2022-04-01             11863                       5.48
# 4 2022-05-01             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
import plotly.express as px

fig = px.line(
    sip,
    x="month",
    y="sip_inflow_crore",
    title="Monthly SIP Inflows (2022-2025)"
)

fig.show()

# %%
fig.add_annotation(
    x="2025-12-01",
    y=31002,
    text="₹31,002 Cr All-Time High",
    showarrow=True
)

fig.show()

# %%
fig.add_annotation(
    x="2025-12-01",
    y=31002,
    text="₹31,002 Cr All-Time High",
    showarrow=True
)

fig.show()

# %%
fig.add_annotation(
    x="2025-12-01",
    y=31002,
    text="₹31,002 Cr All-Time High",
    showarrow=True
)

fig.show()

# %%
fig.write_html(
    r"E:\bluestock_mf_capstone\reports\charts\sip_trend.html"
)

# %%
import plotly.express as px

fig = px.line(
    sip,
    x="month",
    y="sip_inflow_crore",
    title="Monthly SIP Inflows (2022-2025)"
)

fig.show()

# %%
sip.head()
# Out:
#        month  sip_inflow_crore  active_sip_accounts_crore  \
# 0 2022-01-01             11517                       4.91
# 1 2022-02-01             11438                       4.93
# 2 2022-03-01             12328                       5.09
# 3 2022-04-01             11863                       5.48
# 4 2022-05-01             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %% [markdown]
# ### Finding 3
#
# Monthly SIP inflows showed consistent growth and reached an all-time high of ₹31,002 crore in December 2025.

# %%
category = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\raw\05_category_inflows.csv"
)

category.head()
# Out:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
print(category.columns)
# Out:
# Index(['month', 'category', 'net_inflow_crore'], dtype='object')

# %%
category["month"] = pd.to_datetime(category["month"])

category.head()
# Out:
#        month         category  net_inflow_crore
# 0 2024-04-01        Large Cap            2413.0
# 1 2024-04-01          Mid Cap            3897.0
# 2 2024-04-01        Small Cap            3533.0
# 3 2024-04-01        Flexi Cap            4947.0
# 4 2024-04-01  Large & Mid Cap            4214.0

# %%
pivot = category.pivot_table(
    values="net_inflow_crore",
    index="category",
    columns="month"
)

pivot.head()
# Out:
# month            2024-04-01  2024-05-01  2024-06-01  2024-07-01  2024-08-01  \
# category
# ELSS                  466.0       553.0       472.0       471.0       499.0
# Flexi Cap            4947.0      5529.0      4478.0      4869.0      5562.0
# Gilt                  784.0       836.0       864.0       959.0       952.0
# Hybrid               2955.0      3487.0      3163.0      3291.0      3684.0
# Large & Mid Cap      4214.0      4368.0      4610.0      5023.0      5411.0
#
# month            2024-09-01  2024-10-01  2024-11-01  2024-12-01  2025-01-01  \
# category
# ELSS                  537.0       537.0       571.0       521.0       516.0
# Flexi Cap            5397.0      6004.0      6111.0      4654.0      5603.0
# Gilt                  925.0       898.0       704.0       831.0       744.0
# Hybrid               3015.0      3314.0      3264.0      3538.0      2967.0
# Large & Mid Cap      4528.0      4581.0      5556.0      4878.0      4816.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,6))

sns.heatmap(
    pivot,
    cmap="YlGnBu"
)

plt.title("Category-wise Net Inflows Heatmap")

plt.show()

# %%
plt.figure(figsize=(14,6))

sns.heatmap(
    pivot,
    cmap="YlGnBu"
)

plt.title("Category-wise Net Inflows Heatmap")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\category_heatmap.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Finding 4
#
# Category inflows varied significantly across months, with certain fund categories attracting consistently higher net investments.

# %%
investor = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\raw\08_investor_transactions.csv"
)

investor.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
print(investor.columns)
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='object')

# %%
age_counts = investor["age_group"].value_counts()

import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))

plt.pie(
    age_counts,
    labels=age_counts.index,
    autopct="%1.1f%%"
)

plt.title("Age Group Distribution")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\age_distribution.png",
    bbox_inches="tight"
)

plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10,6))

sns.boxplot(
    data=investor,
    x="age_group",
    y="amount_inr"
)

plt.title("Investment Amount by Age Group")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\sip_boxplot.png",
    bbox_inches="tight"
)

plt.show()

# %%
gender_counts = investor["gender"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct="%1.1f%%"
)

plt.title("Gender Distribution")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\gender_split.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Finding 5
#
# The majority of investors belong to the dominant age group shown in the age distribution chart.

# %% [markdown]
# ### Finding 6
#
# Investment amounts vary across age groups, with some groups showing higher median investment values.

# %% [markdown]
# ### Finding 7
#
# The investor base shows a measurable gender distribution across mutual fund participants.

# %%
state_data = (
    investor.groupby("state")["amount_inr"]
    .sum()
    .sort_values(ascending=True)
)

plt.figure(figsize=(10,8))

state_data.plot(kind="barh")

plt.title("SIP Amount by State")
plt.xlabel("Amount (INR)")
plt.ylabel("State")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\state_distribution.png",
    bbox_inches="tight"
)

plt.show()

# %%
tier_counts = investor["city_tier"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    tier_counts,
    labels=tier_counts.index,
    autopct="%1.1f%%"
)

plt.title("T30 vs B30 Distribution")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\t30_b30.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Finding 8
#
# A few states contribute a significantly larger share of total SIP investments compared to others.

# %% [markdown]
# ### Finding 9
#
# T30 cities account for a major share of investor participation, though B30 cities continue to contribute meaningfully.

# %%
folio = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\raw\06_industry_folio_count.csv"
)

folio.head()
# Out:
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
print(folio.columns)
# Out:
# Index(['month', 'total_folios_crore', 'equity_folios_crore',
#        'debt_folios_crore', 'hybrid_folios_crore', 'others_folios_crore'],
#       dtype='object')

# %%
folio["month"] = pd.to_datetime(folio["month"])

folio.head()
# Out:
#        month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0 2022-01-01               13.26                 9.28               1.86
# 1 2022-04-01               13.91                 9.74               1.95
# 2 2022-07-01               13.85                 9.69               1.94
# 3 2022-10-01               14.12                 9.88               1.98
# 4 2023-01-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.plot(
    folio["month"],
    folio["total_folios_crore"],
    marker="o"
)

plt.title("Industry Folio Count Growth (2022-2025)")
plt.xlabel("Month")
plt.ylabel("Total Folios (Crore)")

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(
    folio["month"],
    folio["total_folios_crore"],
    marker="o"
)

plt.annotate(
    "13.26 Cr",
    xy=(folio["month"].iloc[0],
        folio["total_folios_crore"].iloc[0])
)

plt.title("Industry Folio Count Growth")
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(
    folio["month"],
    folio["total_folios_crore"],
    marker="o"
)

plt.annotate(
    "13.26 Cr",
    xy=(folio["month"].iloc[0],
        folio["total_folios_crore"].iloc[0])
)

plt.annotate(
    "26.12 Cr",
    xy=(folio["month"].iloc[-1],
        folio["total_folios_crore"].iloc[-1])
)

plt.title("Industry Folio Count Growth (2022-2025)")
plt.xlabel("Month")
plt.ylabel("Total Folios (Crore)")

plt.grid(True)

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\folio_growth.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Finding 10
#
# Industry folio count nearly doubled between 2022 and 2025, reflecting strong growth in retail participation in mutual funds.

# %%
nav = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\raw\02_nav_history.csv"
)

nav.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
print(nav.columns)
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='object')

# %%
nav["date"] = pd.to_datetime(nav["date"])

nav.head()
# Out:
#    amfi_code       date      nav
# 0     119551 2022-01-03  54.3856
# 1     119551 2022-01-04  54.3474
# 2     119551 2022-01-05  54.6869
# 3     119551 2022-01-06  55.4550
# 4     119551 2022-01-07  55.3692

# %%
nav_pivot = nav.pivot(
    index="date",
    columns="amfi_code",
    values="nav"
)

nav_pivot.head()
# Out:
# amfi_code     100016   100025    100033    101206   101207    101208   102885  \
# date
# 2022-01-03  520.4608  26.3169  107.3758  305.0996  38.5736  310.7415  89.8728
# 2022-01-04  515.0971  26.2234  105.9447  305.4514  38.1545  310.6977  90.8724
# 2022-01-05  521.7239  26.2221  105.4800  306.6324  38.1775  310.8165  90.1565
# 2022-01-06  515.7880  26.1728  104.9350  305.9800  37.0665  310.7719  91.5338
# 2022-01-07  515.1639  26.2261  104.3318  304.0480  37.9845  310.8388  90.6762
#
# amfi_code     102886    102887   118632  ...   120843     120844    125497  \
# date                                     ...
# 2022-01-03  119.2905  191.0721  42.8339  ...  49.9131  3180.6318  560.1443
# 2022-01-04  120.6402  189.0737  42.8033  ...  50.8195  3181.4042  560.7052
# 2022-01-05  121.4580  188.0701  43.0564  ...  50.1942  3182.8754  563.0884
# 2022-01-06  125.2386  190.4545  43.2088  ...  50.6213  3184.9450  561.0675
# ...

# %%
returns = nav_pivot.pct_change()

returns.head()
# Out:
# amfi_code     100016    100025    100033    101206    101207    101208  \
# date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.010306 -0.003553 -0.013328  0.001153 -0.010865 -0.000141
# 2022-01-05  0.012865 -0.000050 -0.004386  0.003866  0.000603  0.000382
# 2022-01-06 -0.011377 -0.001880 -0.005167 -0.002128 -0.029101 -0.000143
# 2022-01-07 -0.001210  0.002036 -0.005748 -0.006314  0.024766  0.000215
#
# amfi_code     102885    102886    102887    118632  ...    120843    120844  \
# date                                                ...
# 2022-01-03       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2022-01-04  0.011122  0.011314 -0.010459 -0.000714  ...  0.018160  0.000243
# 2022-01-05 -0.007878  0.006779 -0.005308  0.005913  ... -0.012304  0.000462
# 2022-01-06  0.015277  0.031127  0.012678  0.003540  ...  0.008509  0.000650
# 2022-01-07 -0.009369 -0.008835 -0.016498 -0.005793  ... -0.013477  0.000176
#
# ...

# %%
selected_funds = returns.columns[:10]

returns_10 = returns[selected_funds]

returns_10.head()
# Out:
# amfi_code     100016    100025    100033    101206    101207    101208  \
# date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.010306 -0.003553 -0.013328  0.001153 -0.010865 -0.000141
# 2022-01-05  0.012865 -0.000050 -0.004386  0.003866  0.000603  0.000382
# 2022-01-06 -0.011377 -0.001880 -0.005167 -0.002128 -0.029101 -0.000143
# 2022-01-07 -0.001210  0.002036 -0.005748 -0.006314  0.024766  0.000215
#
# amfi_code     102885    102886    102887    118632
# date
# 2022-01-03       NaN       NaN       NaN       NaN
# 2022-01-04  0.011122  0.011314 -0.010459 -0.000714
# 2022-01-05 -0.007878  0.006779 -0.005308  0.005913
# 2022-01-06  0.015277  0.031127  0.012678  0.003540
# 2022-01-07 -0.009369 -0.008835 -0.016498 -0.005793

# %%
corr_matrix = returns_10.corr()

corr_matrix.head()
# Out:
# amfi_code    100016    100025    100033    101206    101207    101208  \
# amfi_code
# 100016     1.000000  0.045567 -0.000006  0.027747  0.016053 -0.033773
# 100025     0.045567  1.000000  0.002150  0.023769 -0.006710  0.018455
# 100033    -0.000006  0.002150  1.000000 -0.018079  0.000351  0.007864
# 101206     0.027747  0.023769 -0.018079  1.000000  0.010202 -0.027230
# 101207     0.016053 -0.006710  0.000351  0.010202  1.000000 -0.007530
#
# amfi_code    102885    102886    102887    118632
# amfi_code
# 100016    -0.093533 -0.005867 -0.023316 -0.026781
# 100025    -0.001038  0.013754 -0.005648 -0.014166
# 100033    -0.034228 -0.018166 -0.036647 -0.013318
# 101206     0.001570  0.007229 -0.006490 -0.005432
# 101207    -0.005929  0.004860  0.002304  0.043384

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm"
)

plt.title("NAV Return Correlation Matrix")

plt.show()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm"
)

plt.title("NAV Return Correlation Matrix")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\correlation_matrix.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Finding 11
#
# Several mutual fund schemes exhibit strong positive correlations, indicating similar market exposure and return patterns.

# %%
portfolio = pd.read_csv(
    r"E:\bluestock_mf_capstone\data\raw\09_portfolio_holdings.csv"
)

portfolio.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
print(portfolio.columns)
# Out:
# Index(['amfi_code', 'stock_symbol', 'stock_name', 'sector', 'weight_pct',
#        'market_value_cr', 'current_price_inr', 'portfolio_date'],
#       dtype='object')

# %%
sector_data = (
    portfolio.groupby("sector")["weight_pct"]
    .sum()
    .sort_values(ascending=False)
)

sector_data.head()
# Out:
# sector
# Banking       652.26
# IT            455.47
# Pharma        407.45
# Automobile    323.65
# Utilities     265.54
# Name: weight_pct, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

plt.pie(
    sector_data,
    labels=sector_data.index,
    autopct="%1.1f%%"
)

centre_circle = plt.Circle(
    (0,0),
    0.70,
    fc="white"
)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Sector Allocation Across Equity Funds")

plt.show()

# %%
plt.figure(figsize=(8,8))

plt.pie(
    sector_data,
    labels=sector_data.index,
    autopct="%1.1f%%"
)

centre_circle = plt.Circle(
    (0,0),
    0.70,
    fc="white"
)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Sector Allocation Across Equity Funds")

plt.savefig(
    r"E:\bluestock_mf_capstone\reports\charts\sector_allocation.png",
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Finding 12
#
# Financials, Technology, and other major sectors account for a significant share of mutual fund portfolio allocations, indicating sector concentration in equity investments.
